# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# df.drop(['id','Unnamed: 32'], axis=1, inplace=True)
# df

# %%
from sklearn.impute import SimpleImputer
columns_to_replace = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']

# %%
df[columns_to_replace] = df[columns_to_replace].replace(0, np.nan)

# %%
df['Outcome'] = df['Outcome'].replace({1:'غير مصاب',0:' مصاب'})
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# 0                       0.627   50  غير مصاب
# 1                       0.351   31      مصاب
# 2                       0.672   32  غير مصاب
# 3                       0.167   21      مصاب
# 4                       2.288   33  غير مصاب
# ..                        ...  ...       ...
# 763                     0.171   63      مصاب
# 764                     0.340   27      مصاب
# 765                     0.245   30      مصاب
# 766                     0.349   47  غير مصاب
# 767                     0.315   23      مصاب
#
# [768 rows x 9 columns]

# %%
X = df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']]
Y = df['Outcome']

imputer = SimpleImputer(strategy='mean')
X = imputer.fit_transform(X)

# %%
df['BMI'] = df['BMI'].fillna(df['BMI'].median())

# %%
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].median())

# %%
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].median())

# %%
df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].median())

# %%
df['DiabetesPedigreeFunction'] = df['DiabetesPedigreeFunction'].fillna(df['DiabetesPedigreeFunction'].median())

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].median())

# %%
x = df.drop(['Outcome'],axis=1)
y = df['Outcome']
x_train,x_test,y_train,y_test = train_test_split(x,y ,random_state=32)

# %%
R=KNeighborsClassifier(n_neighbors=1)
R.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred = lr.predict(x_test)
pred
# Out:
# array(['غير مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب'], dtype=object)

# %%
rv = np.array(y_test)
rv
# Out:
# array(['غير مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', 'غير مصاب',
#        'غير مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب', ' مصاب',
#        'غير مصاب', 'غير مصاب', ' مصاب', 'غير مصاب', 'غير مصاب', ' مصاب',
#        'غير مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب', ' مصاب',
#        ' مصاب', ' مصاب', ' مصاب', ' مصاب', ' مصاب', 'غير مصاب'],
#       dtype=object)

# %%
accuracy_sklearn = accuracy_score(y_test,pred)*100
print(f'model accuracy: {accuracy_sklearn}')
# Out:
# model accuracy: 79.16666666666666

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
print("Accuracy of SVM classifier on traninig set: {}"
      .format(svm.score(x_train, y_train)))
print("Accuracy of SVM classifier on test set: {}"
      .format(svm.score(x_test, y_test)))
# Out:
# Accuracy of SVM classifier on traninig set: 0.7552083333333334
# Accuracy of SVM classifier on test set: 0.8072916666666666

# %%
predicted_labels = svm.predict(x_test)

# %%
print ('Accuracy of R classifier on training set: {}%'.format(R.score(x_train, y_train) * 100))
print ('Accuracy of R classifier on test set: {}%'.format(R.score(x_test, y_test) * 100))

y_pred =R.predict(x_test)
# Out:
# Accuracy of R classifier on training set: 100.0%
# Accuracy of R classifier on test set: 69.79166666666666%

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age   Outcome
# 0                       0.627   50  غير مصاب
# 1                       0.351   31      مصاب
# 2                       0.672   32  غير مصاب
# 3                       0.167   21      مصاب
# 4                       2.288   33  غير مصاب
# ..                        ...  ...       ...
# 763                     0.171   63      مصاب
# 764                     0.340   27      مصاب
# 765                     0.245   30      مصاب
# 766                     0.349   47  غير مصاب
# 767                     0.315   23      مصاب
#
# [768 rows x 9 columns]
